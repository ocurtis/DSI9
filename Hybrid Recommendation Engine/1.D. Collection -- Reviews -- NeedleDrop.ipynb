# %% [markdown]
# # Collection -- Reviews -- NeedleDrop

# %% [markdown]
# In this notebook, we're going to tackle collecting reviews from TheNeedleDrop, a prominent critic on Youtube. In order to do this, we are going to have to access the closed caption text that accompanies his videos. We'll also take our own scraped data set and combine it with an older, but extensive, dataset we retrieved from Kaggle. The reason we are going to combine is two-fold: closed captions are not always available and can be turned off at any point by a content creator; second, our Kaggle dataset is only through part of 2018.
#
# The workflow is as follows:
#  1. We'll leverage a library called **YoutubeDataAPI** which is a simple python wrapper around YT API calls.
#  2. From there, we will extract **video_ids** from relevant NeedleDrop playlists
#  3. With our video_ids, we will pass these into **YoutubeTranscriptAPI**, a disparate wrapper for grabbing CC
#  4. With our own collected data in place, we will clean in and merge with the pre-existing dataset

# %%
import pandas as pd
from youtube_api import YouTubeDataAPI
from youtube_transcript_api import YouTubeTranscriptApi

# %% [markdown]
# ## My NeedleDrop Pull

# %%
#We're going to need to leverage our Youtube API key to grab ND YT content. We'll do this with a pre-existing python wrapper
api_key = 'AIzaSyCEk20yodR-1N8LL05hD1eJymyf1C1owKQ'

#Instantiate a YT object with our API key
yt = YouTubeDataAPI(api_key)

# %%
#Get playlists for our channel
needle_drop_playlists = yt.get_playlists(yt.get_channel_id_from_user("theneedledrop"))

# %%
#There are two types of playlists, each may have relevant content. One is the classics
needle_drop_classics_id = needle_drop_playlists[11]['playlist_id']

#...the other is hip hop
needle_drop_hiphop_id = needle_drop_playlists[12]['playlist_id']

# %%
#The API call seems to miss the first page of results when a "next page token is passed". 
#So we'll start by pulling and storing all our next pages
#We'll then go back and grab our original page results

check2class = pd.DataFrame(yt.get_videos_from_playlist_id(needle_drop_hiphop_id, next_page_token='CDIQAA'))
check1class = pd.DataFrame(yt.get_videos_from_playlist_id(needle_drop_hiphop_id))

check2 = pd.DataFrame(yt.get_videos_from_playlist_id(needle_drop_classics_id, next_page_token='CDIQAA'))
check1 = pd.DataFrame(yt.get_videos_from_playlist_id(needle_drop_classics_id))

# %%
#Merge and drop any duplicates we may have seen
needle_classic  = pd.concat([check1class, check2class]).drop_duplicates()
needle_hiphop  = pd.concat([check1, check2]).drop_duplicates()

# %%
#Now we'll grab our unique list of video ids and move into the next phase
needle_hip_hop= pd.concat([needle_hiphop,needle_classic]).drop_duplicates('video_id')

# %% [markdown]
# ## Grab CC

# %%
#We'll take a moment to set up our lists. These will then be read into a dataframe at the end
video_id_list = []
review_text_full=[]
video_titles=[]
video_description=[]
video_tags=[]

#Iterate through each video we have in our list
for video_id in list(needle_hip_hop['video_id']):
    
    
    try:
        #try grabbing the video title, description, and tags      
        response = YouTubeTranscriptApi.get_transcript(video_id)        
        video_titles.append(yt.get_video_metadata(video_id)['video_title'])
        video_description.append(yt.get_video_metadata(video_id)['video_description'])
        video_tags.append(yt.get_video_metadata(video_id)['video_tags'])
        
        #prep a list to store review caption text
        review_text = []
        
        #iterate through our response and join our text together
        for i in range(len(response)):
            review_text.append(response[i]['text'])

        review_text_join = " ".join(review_text)
        review_text_full.append(review_text_join)
        video_id_list.append(video_id)
        
    except:
        #If we couldn't grab anything because captions are disabled, just move on and leave these blank
        review_text_full.append('')
        video_id_list.append(video_id)
        video_titles.append('')
        video_description.append('')
        video_tags.append('')

# %%
#Read our results into a dataframe
temp_test_needle_df =pd.DataFrame({
        'review_text' : review_text_full,
        'video_id' : video_id_list,
        'video_titles' : video_titles,
        'video_descrip' : video_description,
        'video_tags' : video_tags,  
})

# %%
#save the results to csv
temp_test_needle_df.to_csv('./needledrop/needle_drop_scraped_needtocheck.csv', index=False)

# %%
#What are we looking at here? YIKES, that's not the cleanest string I've ever seen
pd.set_option('display.max_colwidth',1000)
temp_test_needle_df[145:146][['video_id','video_titles','video_descrip']]
# Out:
#         video_id                                         video_titles  \
# 157  qbh0s7OCZOE  A$AP Mob - Cozy Tapes Vol. 2: Too Cozy ALBUM REVIEW
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  video_descrip
# 157  Listen: https://www.youtube.com/watch?v=LtlO4FVzXew&ab_channel=asapmobVEVO\n\nIt's telling that one of the few highlights on Cozy Tapes Vol. 2 is a track with little to no A$AP Mob presence.\n\nMore hip hop reviews: https://www.youtube.com/playlist?list=PLP4CSgl7K7ormBIO138tYonB949PHnNcP\n\nBuy this album: http://amzn.to/2wlwFHU\n\n===================================\nSubscribe: http://bit.ly/1pBqGCN\n\nOfficial site: http://theneedledrop.com\n\nTND Twitter: http://twitter.com/theneedledrop\n\nTND Facebook: http://facebook.com/theneedledrop\n\nSupport TND: http://theneedledrop.com/support\n===================================\n\nFAV TRACKS: GET THE BAG, BAHAMAS, WHAT HAPPENS, RAF\n\nLEAST FAV TRACK: PLEASE SHUT UP\n\nA$AP MOB - COZY TAPES VOL. 2: TOO COZY / 2017 / RCA / EAST COAST HIP HOP, TRAP RAP, CLOUD RAP\n\n4/10\n\nY'all know this is just my opinion, right?

# %% [markdown]
# ## Kaggle NeedleDrop Pull

# %% [markdown]
# Read In

# %%
#We're going to combine our dataset with a separate Needle Drop review csv we found via Kaggle
kaggle_needle = pd.read_csv('./needledrop/fantano_reviews.csv', encoding='latin-1')
kaggle_needle_captions = pd.read_csv('./needledrop/captions.csv', encoding='latin-1')

# %%
#There was an errant column in each of these csvs, drop them
kaggle_needle_captions = kaggle_needle_captions.drop(columns=['Unnamed: 0'])
kaggle_needle = kaggle_needle.drop(columns=['Unnamed: 0'])

# %%
#Merge on unique link and check the shape
kaggle_needle = pd.merge(kaggle_needle,kaggle_needle_captions,on='link', how='left')
kaggle_needle.shape
# Out:
# (1734, 10)

# %% [markdown]
# Clean

# %%
#clean our video_ids so we can compare
kaggle_needle['video_id'] = kaggle_needle['link'].str.replace('https://www.youtube.com/watch?','')
kaggle_needle['video_id'] = kaggle_needle['video_id'].str.replace('?','')
kaggle_needle['video_id'] = kaggle_needle['video_id'].str.replace('v=','')

# %%
kaggle_needle.columns
# Out:
# Index(['title', 'artist', 'review_date', 'review_type', 'score', 'word_score',
#        'best_tracks', 'worst_track', 'link', 'caption', 'video_id'],
#       dtype='object')

# %% [markdown]
# Compare / Find Overlap

# %%
#Let's compare our data set to this one, do we have more reviews? 
overlap_df = pd.merge(temp_test_needle_df,kaggle_needle, on='video_id', how='left')

# %%
overlap_df.loc[overlap_df['review_date'].isnull()].count()[0]
# Out:
# 130

# %% [markdown]
# ..There are 130 reviews that we picked up that are not in this data set. We will take the time to clean our reviews and append dfs

# %%
#grab the additional video ids
video_id_additions = list(overlap_df.loc[overlap_df['review_date'].isnull(),'video_id'])
needle_additions_df  = temp_test_needle_df[temp_test_needle_df['video_id'].isin(video_id_additions)]

# %%
#Let's take a look and make sure they look like hip hop albums
pd.set_option('display.max_colwidth',100)
needle_additions_df.head()
# Out:
#       video_id  \
# 0  gmKru-Is0SA
# 1  jtPlfmhPnNg
# 2  V2ZTJ8oD4TQ
# 5  zcn-Kp_OWfI
# 6  ZGmQ9_ceFoY
#
#                                                                                            review_text  \
# 0  [Music] hi everyone gee thinnies uh Stan oh here the Internet's busiest music nerd and it's time...
# 1  ah hi everyone ghoul that he's spooked a now here the Internet's creepiest music nerd and it's t...
# 2  hi everyone vibe the new check tan oh here the Internet's busiest music nerd and it's time for a...
# 5  hi everyone fly the kite Tanana here the Internet's busiest music nerd and it is time for a revi...
# 6  Oh hi everyone Anthony Fantana here intranets busiest music nerd and it's time for a review of t...
#
#                                                    video_titles  \
# 0                       Kanye West - Jesus Is King ALBUM REVIEW
# 1  clipping. - There Existed an Addiction to Blood ALBUM REVIEW
# 2                   Danny Brown - uknowhatimsayin¿ ALBUM REVIEW
# 5                               Ameer Vann - Emmanuel EP REVIEW
# 6          JPEGMAFIA - All My Heroes Are Cornballs ALBUM REVIEW
#
#                                                                                          video_descrip  \
# 0  Listen: https://www.youtube.com/watch?v=AOBQkHy8_p8\n\nKanye's unstoppable egoism and lack of fo...
# 1  Listen: https://www.youtube.com/watch?v=fIrpLBShe1A\n\nMake room in your annual Halloween-time m...
# 2  Listen: https://www.youtube.com/watch?v=zcloEzJU27E\n\nFor the most part, uknowhatimsayin¿ is an...
# 5  Listen: https://www.youtube.com/watch?v=Sd6yXx5ytyI\n\nAmeer Vann's comeback EP is pretty bitter...
# 6  Listen: https://www.youtube.com/watch?v=d6U8waR9smg\n\nI’m not disappointed. That’s for sure. \n...
#
#                                                                                             video_tags
# 0  album|review|music|reviews|indie|underground|new|latest|lyrics|full song|listen|track|concert|li...
# 1  album|review|music|reviews|indie|underground|new|latest|lyrics|full song|listen|track|concert|li...
# 2  album|review|music|reviews|indie|underground|new|latest|lyrics|full song|listen|track|concert|li...
# 5  album|review|music|reviews|indie|underground|new|latest|lyrics|full song|listen|track|concert|li...
# 6  album|review|music|reviews|indie|underground|new|latest|lyrics|full song|listen|track|concert|li...

# %%
#Save what we have so far, then read back in
needle_additions_df.to_csv('./needledrop/additions_unclean_for_kaggle_data.csv', index=False)
needle_additions_df= pd.read_csv('./needledrop/additions_unclean_for_kaggle_data.csv')

# %% [markdown]
# ### Clean

# %%
pd.set_option('display.max_rows',100)
needle_additions_df.head(100)
# Out:
#        video_id                                        review_text  \
# 0   gmKru-Is0SA  [Music] hi everyone gee thinnies uh Stan oh he...
# 1   jtPlfmhPnNg  ah hi everyone ghoul that he's spooked a now h...
# 2   V2ZTJ8oD4TQ  hi everyone vibe the new check tan oh here the...
# 3   zcn-Kp_OWfI  hi everyone fly the kite Tanana here the Inter...
# 4   ZGmQ9_ceFoY  Oh hi everyone Anthony Fantana here intranets ...
# 5   D95K29ZTxpo  Oh Oh a b c d e f g tan oh here the internet's...
# 92  ljtIQkFRL1g  my god hi everyone here the Internet's busiest...
# 93  t7-aROT2eqo  what is going on here inch flannel this shirt ...
# 94  _LEQYT-ffsM  okay hi everyone Denis tanno here the Internet...
# 95  FJwmTnjDkrI  hi everyone clear ffunny throat Anna here the ...
# 96  kXkSqBW2wTs  a hi everybody Iceman here the Internet's busi...
# 97  DbKWD0CYuX0  I hate shooting in the morning hi everyone wak...
# 98  9rkFbKVownA  Hi everyone! AHHHHHH AHHHHHH AHHHHHH here, the...
# 99  lZp0ZTzHCuQ  ah hi everybody rainy thneed a tan out here th...
#
#                                          video_titles  \
# 0                          KANYE WEST - JESUS IS KING
# 1     CLIPPING. - THERE EXISTED AN ADDICTION TO BLOOD
# 2                      DANNY BROWN - UKNOWHATIMSAYIN¿
# 3                               AMEER VANN - EMMANUEL
# 4             JPEGMAFIA - ALL MY HEROES ARE CORNBALLS
# 5                                   IDK - IS HE REAL?
# 6                              EARTHGANG - MIRRORLAND
# 7                  POST MALONE - HOLLYWOOD'S BLEEDING
# 8             DRAKE - CARE PACKAGE COMPILATION REVIEW
# 9                             RICH BRIAN - THE SAILOR
# 10                          YBN CORDAE - THE LOST BOY
# 11                    CHANCE THE RAPPER - THE BIG DAY
# 12                BENNY THE BUTCHER - THE PLUGS I MET
# 13                    BIG K.R.I.T. - K.R.I.T. IZ HERE
# 14           DREAMVILLE - REVENGE OF THE DREAMERS III
# 15             PI'ERRE BOURNE - THE LIFE OF PI'ERRE 4
# 16                                       JADEN - ERYS
# 17                   FREDDIE GIBBS & MADLIB - BANDANA
# 18                                      LIL NAS X - 7
# 19                        MEGAN THEE STALLION - FEVER
# 20            YOUNG NUDY & PI'ERRE BOURNE - SLI'MERRE
# 21                       INJURY RESERVE - SELF-TITLED
# 22                          TYLER, THE CREATOR - IGOR
# 23            LOGIC - CONFESSIONS OF A DANGEROUS MIND
# 24        RICO NASTY & KENNY BEATS - ANGER MANAGEMENT
# 25                           SCHOOLBOY Q - CRASH TALK
# 26                      KEVIN ABSTRACT - ARIZONA BABY
# 27              YOUR OLD DROOG - IT WASN'T EVEN CLOSE
# 28                               DOS MONOS - DOS CITY
# 29                             LIZZO - CUZ I LOVE YOU
# 30                               ARIES - WELCOME HOME
# 31          BILLY WOODS & KENNY SEGAL - HIDING PLACES
# 32                                 DAVE - PSYCHODRAMA
# 33                            LITTLE SIMZ - GREY AREA
# 34  BLU & OH NO - A LONG RED HOT LOS ANGELES SUMME...
# 35                               OFFSET - FATHER OF 4
# 36                            GUNNA - DRIP OR DROWN 2
# 37                         LIL PUMP - HARVERD DROPOUT
# 38  CZARFACE & GHOSTFACE KILLAH - CZARFACE MEETS G...
# 39                                DRAKE - SO FAR GONE
# 40                            COMETHAZINE - BAWSKEE 2
# 41                      BOOGIE - EVERYTHINGS FOR SALE
# 42                           MALIBU KEN - SELF-TITLED
# 43                                 FUTURE - THE WIZRD
# 44              BIG K.R.I.T. - TDT COMPILATION REVIEW
# 45                               BAD BUNNY - X 100PRE
# 46                21 SAVAGE - I AM GREATER THAN I WAS
# 47                          MEEK MILL - CHAMPIONSHIPS
# 48  BLACK THOUGHT & SALAAM REMI - STREAMS OF THOUG...
# 49                               XXXTENTACION - SKINS
# 50                  SKI MASK THE SLUMP GOD - STOKELEY
# 51                   EARL SWEATSHIRT - SOME RAP SONGS
# 52                                 J.I.D - DICAPRIO 2
# 53                                6IX9INE - DUMMY BOY
# 54  TYLER, THE CREATOR - MUSIC INSPIRED BY ILLUMIN...
# 55              TRIPPIE REDD - A LOVE LETTER TO YOU 3
# 56  JADEN SMITH - THE SUNSET TAPES: A COOL TAPE STORY
# 57                      ACTION BRONSON - WHITE BRONCO
# 58      LIL PEEP - COME OVER WHEN YOU'RE SOBER, PT. 2
# 59           METRO BOOMIN - NOT ALL HEROES WEAR CAPES
# 60                          TAKEOFF - THE LAST ROCKET
# 61    CURREN$Y, FREDDIE GIBBS & THE ALCHEMIST - FETTI
# 62                                VINCE STAPLES - FM!
# 63                       LIL YACHTY - NUTHIN' 2 PROVE
# 64                FUTURE & JUICE WRLD - WRLD ON DRUGS
# 65  OPEN MIKE EAGLE - WHAT HAPPENS WHEN I TRY TO R...
# 66           CITY MORGUE - VOL. 1: HELL OR HIGH WATER
# 67                               QUAVO - QUAVO HUNCHO
# 68                                 SHECK WES - MUDBOY
# 69                                       LOGIC - YSIV
# 70                           LIL WAYNE - THA CARTER V
# 71                          LUPE FIASCO - DROGAS WAVE
# 72                         BROCKHAMPTON - IRIDESCENCE
# 73                   6LACK - EAST ATLANTA LOVE LETTER
# 74                                   NONAME - ROOM 25
# 75                                         RUSS - ZOO
# 76         $UICIDEBOY$ - I WANT TO DIE IN NEW ORLEANS
# 77                           ARMAND HAMMER - PARAFFIN
# 78                                  EMINEM - KAMIKAZE
# 79    HERMIT AND THE RECLUSE - ORPHEUS VS. THE SIRENS
# 80     YOUNG THUG - SLIME LANGUAGE COMPILATION REVIEW
# 81                       TRIPPIE REDD - LIFE'S A TRIP
# 82                                NICKI MINAJ - QUEEN
# 83                     VALEE - GOOD JOB, YOU FOUND ME
# 84                              MAC MILLER - SWIMMING
# 85                                YG - STAY DANGEROUS
# 86                          TRAVIS SCOTT - ASTROWORLD
# 87                              DENZEL CURRY - TA13OO
# 88                      88RISING - HEAD IN THE CLOUDS
# 89             BUSDRIVER - ELECTRICITY IS ON OUR SIDE
# 90                   THE CARTERS - EVERYTHING IS LOVE
# 91                              JAY ROCK - REDEMPTION
# 92                                   DRAKE - SCORPION
# 93                                 RICO NASTY - NASTY
# 94                                        NAS - NASIR
# 95                                 BLADEE - RED LIGHT
# 96  BLACK THOUGHT & 9TH WONDER - STREAMS OF THOUGH...
# 97                         TIERRA WHACK - WHACK WORLD
# 98                      KIDS SEE GHOSTS - SELF-TITLED
# 99               JUICE WRLD - GOODBYE & GOOD RIDDANCE
#
#                                         video_descrip  \
# 0   Listen: https://www.youtube.com/watch?v=AOBQkH...
# 1   Listen: https://www.youtube.com/watch?v=fIrpLB...
# 2   Listen: https://www.youtube.com/watch?v=zcloEz...
# 71  album|review|music|reviews|indie|underground|n...
# 72  album|review|music|reviews|indie|underground|n...
# 73  album|review|music|reviews|indie|underground|n...
# 74  album|review|music|reviews|indie|underground|n...
# 75  album|review|music|reviews|indie|underground|n...
# 76  album|review|music|reviews|indie|underground|n...
# 77  album|review|music|reviews|indie|underground|n...
# 78  album|review|music|reviews|indie|underground|n...
# 79  album|review|music|reviews|indie|underground|n...
# 80  album|review|music|reviews|indie|underground|n...
# 81  album|review|music|reviews|indie|underground|n...
# 82  album|review|music|reviews|indie|underground|n...
# 83  album|review|music|reviews|indie|underground|n...
# 84  album|review|music|reviews|indie|underground|n...
# 85  album|review|music|reviews|indie|underground|n...
# 86  album|review|music|reviews|indie|underground|n...
# 87  album|review|music|reviews|indie|underground|n...
# 88  album|review|music|reviews|indie|underground|n...
# 89  album|review|music|reviews|indie|underground|n...
# 90  album|review|music|reviews|indie|underground|n...
# 91  album|review|music|reviews|indie|underground|n...
# 92  album|review|music|reviews|indie|underground|n...
# 93  album|review|music|reviews|indie|underground|n...
# 94  album|review|music|reviews|indie|underground|n...
# 95  album|review|music|reviews|indie|underground|n...
# 96  album|review|music|reviews|indie|underground|n...
# 97  album|review|music|reviews|indie|underground|n...
# 98  album|review|music|reviews|indie|underground|n...
# 99  album|review|music|reviews|indie|underground|n...

# %%
#From what we can see there are a number of issudes with the video titles. 
#These are for the most part Artist and Album names, and it will be important later that we have clean versions
needle_additions_df['video_titles'] = needle_additions_df['video_titles'].str.upper().replace(' EP REVIEW','')
needle_additions_df['video_titles'] = needle_additions_df['video_titles'].str.upper().replace(' ALBUM REVIEW','')
needle_additions_df['video_titles'] = needle_additions_df['video_titles'].str.upper().replace(' MIXTAPE REVIEW','')
needle_additions_df['video_titles'] = needle_additions_df['video_titles'].str.upper().replace(' COMPILATION','')

# %%
#Separate the artist and albums
pd.DataFrame(needle_additions_df['video_titles'].str.split('-').values.tolist(), columns=['artist', 'album'])

# %%
#grab clean artists and albums, then rewrite them back into our dataframe
clean_artists = list(pd.DataFrame(needle_additions_df['video_titles'].str.split('-').values.tolist())[0])
clean_albums = list(pd.DataFrame(needle_additions_df['video_titles'].str.split('-').values.tolist())[1])
needle_additions_df['artist_name'] = clean_artists
needle_additions_df['album_name'] = clean_albums

# %% [markdown]
# ### Combine

# %%
#rename columns for consistency
needle_additions_df = needle_additions_df.rename(columns={'artist_name':'artist', 'album_name':'title', 'review_text': 'caption'})

# %%
needle_additions_df.columns
# Out:
# Index(['video_id', 'caption', 'video_titles', 'video_descrip', 'video_tags',
#        'artist', 'title'],
#       dtype='object')

# %%
kaggle_needle.columns
# Out:
# Index(['title', 'artist', 'review_date', 'review_type', 'score', 'word_score',
#        'best_tracks', 'worst_track', 'link', 'caption', 'video_id'],
#       dtype='object')

# %%
kaggle_needle.shape
# Out:
# (1734, 11)

# %%
#merge our dataframes together and save to csv
kaggle_needle = kaggle_needle.append(needle_additions_df[['artist', 'title', 'caption']],ignore_index=True)
kaggle_needle.to_csv('./needledrop/combined_needle_review_data.csv', index=False)
